# %%
import pandas as pd
import re
import numpy as np

# %%
df = pd.read_csv("../data/curated/data.csv")
df.head()
# Out:
#                                                  url  postcode   longitude  \
# 0  https://www.domain.com.au/9-21-rockley-road-so...      3141  144.999757
# 1  https://www.domain.com.au/35-233-canterbury-ro...      3182  144.976195
# 2  https://www.domain.com.au/2-31-howitt-street-s...      3141  145.002817
# 3  https://www.domain.com.au/2-17-railway-parade-...      3163  145.069344
# 4  https://www.domain.com.au/4-653-park-street-br...      3056  144.964991
#
#     latitude  price  bed  bath  parking  \
# 0 -37.837338  400.0    1     1      1.0
# 1 -37.859150  360.0    1     1      1.0
# 2 -37.846776  320.0    1     1      NaN
# 3 -37.891722  360.0    1     1      1.0
# 4 -37.778276  380.0    1     1      1.0
#
#                                                 desc  cbd_dist
# 0  LIGHT, LOCATION AND IMPRESSIVE ENHANCEMENTS In...    5.9614
# 1  PLEASE NOTE THAT THIS PROPERTY IS OFFERED UN-F...    4.1882
# 2  ARRANGE AN INSPECTION TIME ONLINE - DETAILS BE...    6.9114
# ...

# %%
school = pd.read_csv("../data/raw/school-locations2022.csv", encoding = 'cp1252')

# %%
sub = school[['School_Name', 'Postal_Postcode']]  # select specific columns for further process
sub = sub.rename(columns = {'Postal_Postcode': 'postcode'})
sub.head()
# Out:
#                               School_Name  postcode
# 0                 Alberton Primary School      3971
# 1  Allansford and District Primary School      3277
# 2                    Avoca Primary School      3467
# 3                   Avenel Primary School      3664
# 4               Warrandyte Primary School      3113

# %%
sub.isnull().sum() # check nan value
# Out:
# School_Name    0
# postcode       0
# dtype: int64

# %%
sub = sub.dropna() # remove null value

# %%
# merge school with rental properties on postcode
join_df = pd.merge(df, sub, on = 'postcode', how = 'inner')

# %%
# for each rental property, get the number of schools in the same postcode area
school_counts = join_df.groupby('url')['School_Name'].count()
school_counts.head()
# Out:
# url
# https://www.domain.com.au/1-04-26-warleigh-grove-brighton-vic-3186-15879283        24
# https://www.domain.com.au/1-07-281-tooronga-road-glen-iris-vic-3146-16075662        6
# https://www.domain.com.au/1-08-91-dow-street-port-melbourne-vic-3207-16108681       9
# https://www.domain.com.au/1-1-anderson-street-south-melbourne-vic-3205-16070759     9
# https://www.domain.com.au/1-1-beaton-place-inverloch-vic-3996-11422060              6
# Name: School_Name, dtype: int64

# %%
# add a new column school_counts which represents the number of schools 
# in the same postcode area with rental properties
all_df = pd.merge(df, school_counts, on = 'url', how = 'left')
all_df = all_df.rename(columns = {'School_Name': 'school_counts'})
all_df.head()
# Out:
#                                                  url  postcode   longitude  \
# 0  https://www.domain.com.au/9-21-rockley-road-so...      3141  144.999757
# 1  https://www.domain.com.au/35-233-canterbury-ro...      3182  144.976195
# 2  https://www.domain.com.au/2-31-howitt-street-s...      3141  145.002817
# 3  https://www.domain.com.au/2-17-railway-parade-...      3163  145.069344
# 4  https://www.domain.com.au/4-653-park-street-br...      3056  144.964991
#
#     latitude  price  bed  bath  parking  \
# 0 -37.837338  400.0    1     1      1.0
# 1 -37.859150  360.0    1     1      1.0
# 2 -37.846776  320.0    1     1      NaN
# 3 -37.891722  360.0    1     1      1.0
# 4 -37.778276  380.0    1     1      1.0
#
#                                                 desc  cbd_dist  school_counts
# 0  LIGHT, LOCATION AND IMPRESSIVE ENHANCEMENTS In...    5.9614           18.0
# 1  PLEASE NOTE THAT THIS PROPERTY IS OFFERED UN-F...    4.1882           15.0
# ...

# %%
# find the index of rental properties which are furnished
furnish_idx = all_df.index[df['desc'].str.contains('furnish|Furnish').fillna(False)] 
furnish_idx
# Out:
# Int64Index([   4,   14,   40,   60,   81,   85,  122,  124,  128,  137,
#             ...
#             3960, 3961, 3963, 3967, 3969, 3972, 3985, 3987, 3990, 3996],
#            dtype='int64', length=397)

# %%
furnish_lst = []
for i in range(len(all_df)):
    furnish_lst.append(0)   ## 0 represents not furnished
for i in range(0, len(furnish_lst)):
    if i in furnish_idx:
        furnish_lst[i] = 1   ## 1 represents furnished

# %%
all_df['furnished'] = furnish_lst
all_df.head()
# Out:
#                                                  url  postcode   longitude  \
# 0  https://www.domain.com.au/9-21-rockley-road-so...      3141  144.999757
# 1  https://www.domain.com.au/35-233-canterbury-ro...      3182  144.976195
# 2  https://www.domain.com.au/2-31-howitt-street-s...      3141  145.002817
# 3  https://www.domain.com.au/2-17-railway-parade-...      3163  145.069344
# 4  https://www.domain.com.au/4-653-park-street-br...      3056  144.964991
#
#     latitude  price  bed  bath  parking  \
# 0 -37.837338  400.0    1     1      1.0
# 1 -37.859150  360.0    1     1      1.0
# 2 -37.846776  320.0    1     1      NaN
# 3 -37.891722  360.0    1     1      1.0
# 4 -37.778276  380.0    1     1      1.0
#
#                                                 desc  cbd_dist  school_counts  \
# 0  LIGHT, LOCATION AND IMPRESSIVE ENHANCEMENTS In...    5.9614           18.0
# 1  PLEASE NOTE THAT THIS PROPERTY IS OFFERED UN-F...    4.1882           15.0
# ...

# %%
all_df = all_df[all_df["price"] < 5000]
all_df = all_df.drop(columns = ['desc'])
all_df.head()
# Out:
#                                                  url  postcode   longitude  \
# 0  https://www.domain.com.au/9-21-rockley-road-so...      3141  144.999757
# 1  https://www.domain.com.au/35-233-canterbury-ro...      3182  144.976195
# 2  https://www.domain.com.au/2-31-howitt-street-s...      3141  145.002817
# 3  https://www.domain.com.au/2-17-railway-parade-...      3163  145.069344
# 4  https://www.domain.com.au/4-653-park-street-br...      3056  144.964991
#
#     latitude  price  bed  bath  parking  cbd_dist  school_counts  furnished
# 0 -37.837338  400.0    1     1      1.0    5.9614           18.0          0
# 1 -37.859150  360.0    1     1      1.0    4.1882           15.0          0
# 2 -37.846776  320.0    1     1      NaN    6.9114           18.0          0
# 3 -37.891722  360.0    1     1      1.0   14.3864           15.0          0
# 4 -37.778276  380.0    1     1      1.0    8.7863            9.0          1

# %%
all_df.to_csv(r'../data/curated/processed_data.csv', index = False)

# %%
#read data for postcode and corresponding sa2 code
sa2=pd.read_excel('../data/raw/post_sa2.xlsx',header=None)
sa2=sa2.iloc[7:5995,[1,2,3]]
sa2_vic_index=[]
#select victoria postcode data
for i in range(7,5995):
    if int(sa2.iloc[:,0][i]) >= 3000 and int(sa2.iloc[:,0][i]) < 4000:
        sa2_vic_index.append(i)
for i in range(0,len(sa2_vic_index)):
    sa2_vic_index[i]=sa2_vic_index[i]-7
sa2_vic=sa2.iloc[sa2_vic_index,:]
sa2_vic.to_csv('../data/curated/vic_post_sa2.csv',header=['postcode','SA2 code','SA2 name'],index=False)

# %%
pop=pd.read_csv('../data/curated/pop_forecast.csv')
#select predict population data
predict_pop=pop[['SA2 code','2022 no.','2023 no.','2024 no.','2025 no.']]
sa2_vic=pd.read_csv('../data/curated/vic_post_sa2.csv')
#join predict population data with sa2-postcode data on postcode
join_vic=pd.merge(predict_pop,sa2_vic,on='SA2 code',how='left')
#calculate mean predict population for each postcode
join_vic=round(join_vic.groupby('postcode')[['2022 no.','2023 no.','2024 no.','2025 no.']].mean()).reset_index()
processed_df=pd.read_csv('../data/curated/processed_data.csv')
#join previous processed data with victoria predict population
predict_data=pd.merge(processed_df,join_vic,on='postcode',how='left')
#remove data with nan and fill nan with 0
predict_data=predict_data.dropna(subset=['2022 no.'])
predict_data=predict_data.fillna(0)
predict_data.to_csv('../data/curated/predict_data.csv',index=False)
predict_data.isnull().sum()
# Out:
# url              0
# postcode         0
# longitude        0
# latitude         0
# price            0
# bed              0
# bath             0
# parking          0
# cbd_dist         0
# school_counts    0
# furnished        0
# 2022 no.         0
# 2023 no.         0
# 2024 no.         0
# 2025 no.         0
# dtype: int64
